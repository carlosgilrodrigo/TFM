# %% [markdown]
# <a href="https://colab.research.google.com/github/carlosgilrodrigo/TFM/blob/main/Clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importación de paquetes
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Lectura de datos
df = pd.read_csv('/content/drive/MyDrive/TFM/datasetLimpio60.csv', decimal='.')

# %%
df
# Out:
#               home_team                 away_team result_full result_ht  \
# 0             blackpool      west bromwich albion         2-1       1-0
# 1             liverpool           manchester city         3-0       3-0
# 2     manchester united                   arsenal         1-0       1-0
# 3            stoke city               aston villa         2-1       0-1
# 4                fulham                   chelsea         0-0       0-0
# ...                 ...                       ...         ...       ...
# 4065          liverpool  brighton and hove albion         0-1       0-0
# 4066            burnley            leicester city         1-1       1-1
# 4067     crystal palace         manchester united         0-0       0-0
# 4068   sheffield united               aston villa         1-0       1-0
# 4069   newcastle united                 liverpool         0-0       0-0
#
#       home_passes  home_possession  home_shots  home_shots_on_target  \
# ...
